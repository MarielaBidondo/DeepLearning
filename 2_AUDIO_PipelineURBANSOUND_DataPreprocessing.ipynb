# %% [markdown]
# # Classifying Urban sounds using Deep Learning
#
# ## 2 Data Preprocessing and Data Splitting

# %% [markdown]
# ### Audio properties that will require normalising
#
# Following on from the previous notebook, we identifed the following audio properties that need preprocessing to ensure consistency across the whole dataset:
#
# - Audio Channels
# - Sample rate
# - Bit-depth
#
# We will continue to use Librosa which will be useful for the pre-processing and feature extraction.

# %% [markdown]
# ### Preprocessing stage
#
# For much of the preprocessing we will be able to use [Librosa's load() function.](https://librosa.github.io/librosa/generated/librosa.core.load.html)
#
# We will compare the outputs from Librosa against the default outputs of [scipy's wavfile library](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.io.wavfile.read.html) using a chosen file from the dataset.
#
# #### Sample rate conversion
#
# By default, Librosa’s load function converts the sampling rate to 22.05 KHz which we can use as our comparison level.

# %% [markdown]
# #### Bit-depth
#
# fold_number = row["fold"]
#     if (fold_number == 1 or fold_number == 2):
#         try:
#             file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(fold_number)+'/',str(row["slice_file_name"]))
#
#             class_label = row["class"] #or class_name (see your UrbanSound8K.csv)
#             data = extract_features(file_name)
#
#             features.append([data, class_label])
#         except Exception as e:
#             print("Error encountered while parsing file: ", file_name)Librosa’s load function will also normalise the data so it's values range between -1 and 1. This removes the complication of the dataset having a wide range of bit-depths.

# %%
import librosa 
from scipy.io import wavfile as wav
import numpy as np

filename = './data/UrbanSound_sample/fold2/14387-9-0-7.wav'

librosa_audio, librosa_sample_rate = librosa.load(filename) 
scipy_sample_rate, scipy_audio = wav.read(filename) 



print('Original sample rate:', scipy_sample_rate) 
print('Librosa sample rate:', librosa_sample_rate)
# Out:
# Original sample rate: 44100
# Librosa sample rate: 22050

# %%
print('Original audio file min~max range:', np.min(scipy_audio), 'to', np.max(scipy_audio))
print('Librosa audio file min~max range:', np.min(librosa_audio), 'to', np.max(librosa_audio))
# Out:
# Original audio file min~max range: -9784 to 8826
# Librosa audio file min~max range: -0.2953764 to 0.24292065

# %% [markdown]
# #### Merge audio channels
#
# Librosa will also convert the signal to mono, meaning the number of channels will always be 1.

# %%
import matplotlib.pyplot as plt

# Original audio with 2 channels 
plt.figure(figsize=(12, 4))
plt.plot(scipy_audio)
# Out:
# [<matplotlib.lines.Line2D at 0x7fa13d4cb0d0>,
#  <matplotlib.lines.Line2D at 0x7fa13d4a8150>]

# %%
# Librosa audio with channels merged 
plt.figure(figsize=(12, 4))
plt.plot(librosa_audio)

# %% [markdown]
# #### Other audio properties to consider
#
# At this stage it is not yet clear whether other factors may also need to be taken into account, such as sample duration length and volume levels.
#
# We will proceed as is for the meantime and come back to address these later if it's perceived to be effecting the validity of our target metrics.

# %% [markdown]
# ### Extract Features
#
# As outlined in the proposal, we will extract [Mel-Frequency Cepstral Coefficients (MFCC)](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum) from the the audio samples.
#
# The MFCC summarises the frequency distribution across the window size, so it is possible to analyse both the frequency and time characteristics of the sound. These audio representations will allow us to identify features for classification.

# %% [markdown]
# #### Extracting a MFCC
#
# For this we will use [Librosa's mfcc() function](https://librosa.github.io/librosa/generated/librosa.feature.mfcc.html) which generates an MFCC from time series audio data.

# %%
mfccs = librosa.feature.mfcc(y=librosa_audio, sr=librosa_sample_rate, n_mfcc=40)  #from the literature the first 13th are the most representative
print(mfccs.shape) #That's 173 samples and 40 Mel-frequency cepstral coefficients
# Out:
# (40, 173)

# %% [markdown]
# **YOUR TURN**: Change n_mfcc=40 to 13 and see differences.

# %% [markdown]
# This shows librosa calculated a series of 40 MFCCs over 173 frames.

# %%
import librosa.display
librosa.display.specshow(mfccs, sr=librosa_sample_rate, x_axis='time')

# %% [markdown]
# #### Extracting MFCC's for every file
#
# We will now extract an MFCC for each audio file in the dataset and store it in a Panda Dataframe along with it's classification label.

# %%
def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')  #kaiser_fast - high resolution
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled

# %% [markdown]
# **YOUR TURN**: Calculate also melspectogram and see the difference on accuracy

# %%
# Load various imports 
import pandas as pd
import os
import librosa


# Set the path to the full UrbanSound dataset 
fulldatasetpath = './data/UrbanSound_sample/'

metadata = pd.read_csv('./data/UrbanSound_sample/UrbanSound8K.csv')


features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    fold_number = row["fold"]
    if (fold_number == 1 or fold_number == 2):
        try:
            file_name = os.path.join(os.path.abspath('./data/UrbanSound_sample/'),'fold'+str(fold_number)+'/',str(row["slice_file_name"]))
            class_label = row["class"]   
            data = Wavfilehelper.read_file_properties(file_name)
            features.append([data, class_label])
        except:
             print("Error encountered while parsing file: ", file_name) 
                
                
                
# Convert into a Panda datafram
    
   # file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    #class_label = row["class"] #or class_name (see your UrbanSound8K.csv)
    #data = extract_features(file_name)
    
    #features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/100652-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/100652-3-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/100652-3-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/100652-3-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/101415-3-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/101415-3-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/101415-3-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102104-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102106-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102305-6-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102842-3-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102842-3-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102842-3-1-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/102842-3-1-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102858-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102858-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/102871-8-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-1-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-3-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-3-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-3-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103074-7-4-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-17.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-19.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/103258-5-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/104817-4-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-19.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-21.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-24.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/105415-2-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-17.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-19.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-20.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/106015-5-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/106905-8-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/106905-8-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/106905-8-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/106905-8-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108041-9-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/108187-3-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/108187-3-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/108187-3-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/108187-3-6-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-21.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-23.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-29.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-30.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/108362-2-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-134.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-153.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-29.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-32.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-48.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/109703-2-0-50.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/112195-3-0-38.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/112195-3-0-48.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/112195-3-0-57.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/112195-3-0-80.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113201-5-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/113205-5-1-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113785-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/113785-3-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/114587-3-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/114587-3-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/114587-3-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/114587-3-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/115537-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118101-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118101-3-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118101-3-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118101-3-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118279-8-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/118723-4-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/118962-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/118963-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/119455-5-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/122690-6-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-17.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-1-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-2-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-2-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-2-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/123688-8-2-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-17.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/124489-9-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/125791-3-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/125791-3-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/125791-3-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/125791-3-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/127872-0-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/127873-0-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/130030-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-20.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/132016-9-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-5-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/132073-1-6-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-14.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-15.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-16.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-19.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-20.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-21.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-22.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-23.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-24.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-25.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-26.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-27.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-28.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/134717-0-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-32.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-37.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-40.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-49.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-50.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-65.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-85.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/135776-2-0-90.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-28.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-30.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-31.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-73.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/137156-9-0-79.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138015-3-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138015-3-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138015-3-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138031-2-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138031-2-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138031-2-0-22.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/138031-2-0-23.wav
# ...
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/78360-4-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-12.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/79377-9-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/83199-9-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/84359-2-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/86278-6-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/86279-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/87275-1-5-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/88466-7-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/89211-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/89212-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/89948-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/9031-3-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/9031-3-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/9031-3-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/9031-3-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/91396-8-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/91396-8-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/91396-8-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/91396-8-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-1-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-1-18.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-1-19.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-1-22.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/93193-9-1-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94401-1-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94710-5-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94710-5-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94710-5-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94710-5-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/94710-5-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/94868-1-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/94868-1-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/94868-1-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/96158-4-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-49.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-55.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-61.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96169-9-1-74.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96475-9-0-9.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-11.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-13.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-3.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/96920-9-0-8.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/97193-3-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/97193-3-0-1.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/97193-3-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/97193-3-0-6.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-22.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-23.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-25.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-28.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-34.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-36.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/97317-2-0-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-0-10.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-0-4.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-0-7.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-1-20.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-1-27.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold2/98202-9-1-5.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-1-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-10-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-2-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-3-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-4-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-5-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-6-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-7-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-8-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/98223-7-9-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-0.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-2.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-36.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-48.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-49.wav
# Error encountered while parsing file:  /Users/mariela/Desktop/DS/DeepLearning/7. DEEP LEARNING/DL_case_study/data/UrbanSound_sample/fold1/99180-9-0-7.wav
# Finished feature extraction from  0  files

# %%
import struct

class WavFileHelper():
    
    def read_file_properties(self, filename):

        wave_file = open(filename,"rb")
        
        riff = wave_file.read(12)
        fmt = wave_file.read(36)
        
        num_channels_string = fmt[10:12]
        num_channels = struct.unpack('<H', num_channels_string)[0]

        sample_rate_string = fmt[12:16]
        sample_rate = struct.unpack("<I",sample_rate_string)[0]
        
        bit_depth_string = fmt[22:24]
        bit_depth = struct.unpack("<H",bit_depth_string)[0]

        return (num_channels, sample_rate, bit_depth)

# %% [markdown]
# ### Convert the data and labels
#
# We will use `sklearn.preprocessing.LabelEncoder` to encode the categorical text data into model-understandable numerical data.

# %%
#pip install keras

# %%
#pip install tensorflow

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y))
# Out:
# Using TensorFlow backend.
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mariela/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/n8/t77_2kqn0_s4h2xx74xfgflh0000gn/T/ipykernel_23613/961909178.py in <module>
#       8 # Encode the classification labels
#       9 le = LabelEncoder()
# ---> 10 yy = to_categorical(le.fit_transform(y))
#
# ~/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      47     y = y.ravel()
#      48     if not num_classes:
# ---> 49         num_classes = np.max(y) + 1
#      50     n = y.shape[0]
#      51     categorical = np.zeros((n, num_classes), dtype=dtype)
#
# <__array_function__ internals> in amax(*args, **kwargs)
#
# ~/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims, initial, where)
#    2732     """
#    2733     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
# -> 2734                           keepdims=keepdims, initial=initial, where=where)
#    2735
#    2736
#
# ~/opt/anaconda3/envs/Deeplearning/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85                 return reduction(axis=axis, out=out, **passkwargs)
#      86
# ---> 87     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      88
#      89
#
# ValueError: zero-size array to reduction operation maximum which has no identity

# %% [markdown]
# ### Split the dataset
#
# Here we will use `sklearn.model_selection.train_test_split` to split the dataset into training and testing sets. The testing set size will be 20% and we will set a random state.

# %%
# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n8/t77_2kqn0_s4h2xx74xfgflh0000gn/T/ipykernel_23613/93597740.py in <module>
#       2 from sklearn.model_selection import train_test_split
#       3
# ----> 4 x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)
#
# NameError: name 'yy' is not defined

# %% [markdown]
# ### Store the preprocessed data

# %%
### store the preprocessed data for use in the next notebook

# %store x_train 
# %store x_test 
# %store y_train 
# %store y_test 
# %store yy 
# %store le

# %% [markdown]
# ### *In the next notebook we will develop our model*
